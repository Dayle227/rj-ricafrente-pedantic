# %% [markdown]
# <h2>Discrete mathematics <b>

# %% [markdown]
# <h4><b>Pedantic coding<b>

# %% [markdown]
# <h5>Coded and Submitted by:<h5>
# <h5><i>Ricafrente, Ric Jhon Dayle D.<i>
# <h5><i>58007<i>

# %% [markdown]
# Question 1
# 50 Points
# Given the English statement:
# Add additional fries and drinks to the order if the customer would buy a
# Cheese Burger Deluxe but add a Sundae instead if they do not. Always remember
# to print the receipt for every transaction.

# %%
Give The English statement

Add Additional fries and drinks to order if the customer would buy a cheese burger deluxe but add a sundae instead if they do not. 
Always remember to print the reciept for every transaction.

r-Add fries q-Add drinks p-The Customer would buy a cheese burher deluxe
s-Add sundae

# %% [markdown]
# ![flor.JPG](attachment:72ac2bbf-c4fe-41a9-be95-3bae558a609e.JPG)
